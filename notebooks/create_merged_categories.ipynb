# %%
import os, sys
#to save json file
sys.path.append(os.path.join(sys.path[0],'../src'))
import data_processing
import util

# %%
annotations="../data/annotations_new_cat.json"
output_json='merged.json'
categories_to_keep=[
    'Paper',
    'Litter',
    'Non-recyclable plastic',
    'Plastic',
    'Metal',
    'Glass',
    'Compost',
    'Battery',
    ]

# %%
#MERGE CATEGORIES
data_processing.create_merged_categories(annotations,output_json,categories_to_keep)
# Out:
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!

# %%
#plot new taxonomy, numer of anotations per category
data_folder="../data"
ouput_json=data_folder+'/'+output_json
util.plot_annotations_per_category(ouput_json)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
