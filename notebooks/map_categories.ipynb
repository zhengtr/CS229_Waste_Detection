# %%
import os, sys
#to save json file
sys.path.append(os.path.join(sys.path[0],'../src'))
import data_processing
import util

# %%
#replace categories using a csv file
original_json='../data/annotations.json'
file_new_classes='../map_TACO.csv'
ouput_json='../data/annotations_TACO_10.json'
data_processing.replace_dataset_classes( original_json, file_new_classes,ouput_json)

# %%
#plot new taxonomy, numer of anotations per category
util.plot_annotations_per_category(ouput_json)
# Out:
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
#               Categories  Number of annotations
# 6                  Other                   1727
# 7  Plastic bag + wrapper                    850
# 3              Cigarette                    667
# 0                 Bottle                    439
# 1             Bottle cap                    289
# 2                    Can                    273
# 4                    Cup                    192
# 9                  Straw                    161
# 8                Pop tab                     99
# 5                    Lid                     87
