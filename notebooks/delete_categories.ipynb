# %%
import os, sys
#to save json file
sys.path.append(os.path.join(sys.path[0],'../src'))
import data_processing
import util

# %%
original_ann_filename='../data/annotations_TACO_10_no_small.json'
output_filename='annotations_TACO_7.json'
remove_category_list=['Pop tab','Lid','Cigarette']
data_processing.drop_categories( original_ann_filename,remove_category_list,output_filename)
# Out:
# creating anotations..
# Finished creating anotations.
# checking for images without annotations
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# Finished deliting files without anotations.

# %%
#plot new taxonomy, numer of anotations per category
output_filename="../data/"+output_filename
util.plot_annotations_per_category(output_filename)
# Out:
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
#               Categories  Number of annotations
# 4                  Other                   1152
# 5  Plastic bag + wrapper                    771
# 0                 Bottle                    409
# 2                    Can                    253
# 3                    Cup                    179
# 1             Bottle cap                    134
# 6                  Straw                    130
